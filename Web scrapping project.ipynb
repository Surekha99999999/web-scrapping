# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get('https://en.wikipedia.org/wiki/Main_Page')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
heading_tags = ['h1','h2','h3']
for tags in soup.find_all(heading_tags):
    print(tags.name + '->' + tags.text.strip())
# Out:
# h1->Main Page
# h2->From today's featured article
# h2->Did you know ...
# h2->In the news
# h2->On this day
# h2->Today's featured picture
# h2->Other areas of Wikipedia
# h2->Wikipedia's sister projects
# h2->Wikipedia languages
# h2->Navigation menu
# h3->Personal tools
# h3->Namespaces
# h3->Variants
# expanded
# collapsed
# h3->Views
# h3->More
# expanded
# collapsed
# h3->Search
# h3->Navigation
# h3->Contribute
# h3->Tools
# h3->Print/export
# h3->In other projects
# h3->Languages

# %%
import pandas as pd

# %% [markdown]
# ### 9) Write a python program to scrape mentioned details from dineout.co.in :

# %%
page = requests.get('https://www.dineout.co.in/delhi-restaurants/buffet-special')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/><link href="/manifest.json" rel="manifest"/><style type="text/css">
#             @font-face {
#                 font-family: 'dineicon';
#                 src:  url('/fonts/dineicon.eot');
#                 src:  url('/fonts/dineicon.eot#iefix') format('embedded-opentype'),
#                 url('/fonts/dineicon.ttf') format('truetype'),
#                 url('/fonts/dineicon.woff') format('woff'),
#                 url('/fonts/dineicon.svg#dineicon') format('svg');
#                 font-weight: normal;
# 				font-style: normal;
# 				font-display: swap;
#             }
#             .hide {
#                 display: none !important;
#             }
#             .async-hide{
#                 opacity: inherit !important;
#             }
# ...

# %%
first_title = soup.find('div', class_ = "restnt-info cursor")
first_title
# Out:
# <div class="restnt-info cursor" data-gatype="RestaurantNameClick"><a analytics-action="RestaurantCardClick" analytics-label="86792_Castle Barbeque" class="restnt-name ellipsis" data-w-onclick="sendAnalyticsCommon|w1-restarant" href="/delhi/castle-barbeque-connaught-place-central-delhi-86792">Castle Barbeque</a><div class="restnt-loc ellipsis" data-w-onclick="stopClickPropagation|w1-restarant"><a data-name="Connaught Place" data-type="LocalityClick" href="/delhi-restaurants/central-delhi/connaught-place">Connaught Place</a>, <a data-name="Central Delhi" data-type="AreaClick" href="/delhi-restaurants/central-delhi">Central Delhi</a></div></div>

# %%
first_title.text
# Out:
# 'Castle BarbequeConnaught Place, Central Delhi'

# %%
loc = soup.find('div',class_ = "restnt-loc ellipsis")
loc.text
# Out:
# 'Connaught Place, Central Delhi'

# %%
sta = soup.find('span',class_ = "double-line-ellipsis")
sta.text
# Out:
# '₹ 2,000 for 2 (approx) | Chinese, North Indian'

# %%
titles = []

for i in soup.find_all('div',class_ ="restnt-info cursor"):
    titles.append(i.text)
    
titles
# Out:
# ['Castle BarbequeConnaught Place, Central Delhi',
#  'Jungle Jamboree3CS Mall,Lajpat Nagar - 3, South Delhi',
#  'Castle BarbequePacific Mall,Tagore Garden, West Delhi',
#  'Cafe KnoshThe Leela Ambience Convention Hotel,Shahdara, East Delhi',
#  'The Barbeque CompanyGardens Galleria,Sector 38A, Noida',
#  'India GrillHilton Garden Inn,Saket, South Delhi',
#  'Delhi BarbequeTaurus Sarovar Portico,Mahipalpur, South Delhi',
#  'The Monarch - Bar Be Que VillageIndirapuram Habitat Centre,Indirapuram, Ghaziabad',
#  'World CafeVibe by The Lalit Traveller,Sector 35, Faridabad',
#  'Indian Grill RoomSuncity Business Tower,Golf Course Road, Gurgaon',
#  'Mad 4 Bar B QueSector 29, Faridabad',
#  'Barbeque 29NIT, Faridabad',
#  'GlasshouseDoubleTree By Hilton Gurugram Baani Square,Sector 50, Gurgaon']

# %%
location = []

for i in soup.find_all('div',class_ = "restnt-loc ellipsis"):
    location.append(i.text)
    
location
# Out:
# ['Connaught Place, Central Delhi',
#  '3CS Mall,Lajpat Nagar - 3, South Delhi',
#  'Pacific Mall,Tagore Garden, West Delhi',
#  'The Leela Ambience Convention Hotel,Shahdara, East Delhi',
#  'Gardens Galleria,Sector 38A, Noida',
#  'Hilton Garden Inn,Saket, South Delhi',
#  'Taurus Sarovar Portico,Mahipalpur, South Delhi',
#  'Indirapuram Habitat Centre,Indirapuram, Ghaziabad',
#  'Vibe by The Lalit Traveller,Sector 35, Faridabad',
#  'Suncity Business Tower,Golf Course Road, Gurgaon',
#  'Sector 29, Faridabad',
#  'NIT, Faridabad',
#  'DoubleTree By Hilton Gurugram Baani Square,Sector 50, Gurgaon']

# %%
price = []

for i in soup.find_all('span',class_ = "double-line-ellipsis"):
    price.append(i.text)
    
price
# Out:
# ['₹ 2,000 for 2 (approx) | Chinese, North Indian',
#  '₹ 1,400 for 2 (approx) | Barbecue, North Indian, Asian, Italian',
#  '₹ 2,000 for 2 (approx) | Chinese, North Indian',
#  '₹ 3,000 for 2 (approx) | Multi-Cuisine, North Indian, Italian, Continental, Mediterranean',
#  '₹ 1,800 for 2 (approx) | Barbecue, Chinese, Mughlai, North Indian',
#  '₹ 2,400 for 2 (approx) | North Indian, Italian, Oriental ',
#  '₹ 1,800 for 2 (approx) | Barbecue, North Indian',
#  '₹ 1,600 for 2 (approx) | North Indian, Chinese, Fast Food',
#  '₹ 900 for 2 (approx) | North Indian, Chinese, Continental',
#  '₹ 2,200 for 2 (approx) | North Indian, Mughlai, Barbecue',
#  '₹ 800 for 2 (approx) | North Indian, Mughlai',
#  '₹ 1,500 for 2 (approx) | North Indian, Chinese, Barbecue',
#  '₹ 3,400 for 2 (approx) | Multi-Cuisine, Asian, European, Italian, North Indian']

# %%
images = []

for i in soup.find_all("img", class_ = "no-img"):
    images.append(i['data-src'])
    
images
# Out:
# ['https://im1.dineout.co.in/images/uploads/restaurant/sharpen/8/k/b/p86792-16062953735fbe1f4d3fb7e.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/a/k/p59633-16046474755fa4fa33c0e92.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/3/j/o/p38113-15959192065f1fcb666130c.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/4/j/v/p406-163401663361651d79326d0.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/7/q/d/p79307-16051787075fad15532bd7c.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/2/v/t/p2687-1482477169585cce712b90f.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/v/f/p52501-16006856545f68865616659.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/3/n/o/p34822-15599107305cfa594a13c24.jpg?tr=tr:n-medium',
# ...

# %%
import pandas as pd
df = pd.DataFrame({'Titles':titles,'Location':location,'Price':price,'Images_url':images})
df
# Out:
#                                                Titles  \
# 0       Castle BarbequeConnaught Place, Central Delhi
# 1   Jungle Jamboree3CS Mall,Lajpat Nagar - 3, Sout...
# 2   Castle BarbequePacific Mall,Tagore Garden, Wes...
# 3   Cafe KnoshThe Leela Ambience Convention Hotel,...
# 4   The Barbeque CompanyGardens Galleria,Sector 38...
# 5     India GrillHilton Garden Inn,Saket, South Delhi
# 6   Delhi BarbequeTaurus Sarovar Portico,Mahipalpu...
# 7   The Monarch - Bar Be Que VillageIndirapuram Ha...
# 8   World CafeVibe by The Lalit Traveller,Sector 3...
# 9   Indian Grill RoomSuncity Business Tower,Golf C...
# 10                Mad 4 Bar B QueSector 29, Faridabad
# 11                          Barbeque 29NIT, Faridabad
# 12  GlasshouseDoubleTree By Hilton Gurugram Baani ...
#
#                                              Location  \
# 0                      Connaught Place, Central Delhi
# 1              3CS Mall,Lajpat Nagar - 3, South Delhi
# ...

# %% [markdown]
# ### 4.Write a python program to scrape product name, price and discounts from https://meesho.com/bags-ladies/pl/p7vbp .

# %%
page = requests.get('https://meesho.com/bags-ladies/pl/p7vbp')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-113318580-2"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-113318580-6"></script><script async="">
#               window.dataLayer = window.dataLayer || [];
#               function gtag(){dataLayer.push(arguments);}
#               gtag('js', new Date());
#
#               gtag('config', 'UA-113318580-2', {
#                 page_path: window.location.pathname,
#               });
#           </script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-ZB97HR591S"></script><script async="">
#               window.dataLayer = window.dataLayer || [];
#               function gtag(){dataLayer.push(arguments);}
#               gtag('js', new Date());
#
#               gtag('config', 'G-ZB97HR591S', {
#                 page_path: window.location.pathname,
#               });
#           </script><script async="">
# ...

# %%
first_title = soup.find('p',class_ = "Text__StyledText-sc-oo0kvp-0 bWSOET NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS")
first_title
# Out:
# <p class="Text__StyledText-sc-oo0kvp-0 bWSOET NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS" color="greyT2" font-size="16px" font-weight="book">Women's Sling Handbag/Purse</p>

# %%
first_title.text
# Out:
# "Women's Sling Handbag/Purse"

# %%
price = soup.find('h5',class_ = "Text__StyledText-sc-oo0kvp-0 hiHdyy")

price
# Out:
# <h5 class="Text__StyledText-sc-oo0kvp-0 hiHdyy" color="greyBase" font-size="24px" font-weight="bold">₹<!-- -->535</h5>

# %%
price.text
# Out:
# '₹535'

# %%
discount = soup.find('span',class_ = "Text__StyledText-sc-oo0kvp-0 lnonyH")

discount
# Out:
# <span class="Text__StyledText-sc-oo0kvp-0 lnonyH" color="greenBase" font-size="16px" font-weight="demi">16<!-- -->% off</span>

# %%
discount.text
# Out:
# '16% off'

# %% [markdown]
# # Mens team

# %%
page = requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')

page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Ranking for ODI teams International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Ranking for ODI teams International Cricket Council" property="og:title"/>
# ...

# %%
first_team = soup.find('span',class_ = "u-hide-phablet")
first_team
# Out:
# <span class="u-hide-phablet">New Zealand</span>

# %%
first_team.text
# Out:
# 'New Zealand'

# %%
match = soup.find('td',class_ = "rankings-block__banner--matches")

match
# Out:
# <td class="rankings-block__banner--matches">17</td>

# %%
match.text
# Out:
# '17'

# %%
point = soup.find('td',class_ = "rankings-block__banner--points")

point
# Out:
# <td class="rankings-block__banner--points">2,054</td>

# %%
point.text
# Out:
# '2,054'

# %%
rating = soup.find('td',class_ = "rankings-block__banner--rating u-text-right")

rating
# Out:
# <td class="rankings-block__banner--rating u-text-right">
#                             121
#                             <span class="circle-branding circle-branding--top"></span>
# <span class="circle-branding circle-branding--bottom"></span>
# </td>

# %%
rating.text
# Out:
# '\n                            121\n                            \n\n'

# %%
teams = []

for i in soup.find_all('span',class_ = "u-hide-phablet"):
    teams.append(i.text)
    
teams
# Out:
# ['New Zealand',
#  'England',
#  'Australia',
#  'India',
#  'South Africa',
#  'Pakistan',
#  'Bangladesh',
#  'West Indies',
#  'Sri Lanka',
#  'Afghanistan',
#  'Netherlands',
#  'Ireland',
#  'Scotland',
#  'Zimbabwe',
#  'Oman',
#  'Nepal',
#  'UAE',
#  'United States',
#  'Namibia',
#  'Papua New Guinea',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
matches = []

for i in soup.find_all('td',class_ = "table-body__cell u-center-text"):
    matches.append(i.text)
    
matches
# Out:
# ['32',
#  '3,793',
#  '28',
#  '3,244',
#  '32',
#  '3,624',
#  '25',
#  '2,459',
#  '27',
#  '2,524',
#  '30',
#  '2,740',
#  '30',
#  '2,523',
#  '32',
#  '2,657',
#  '17',
#  '1,054',
#  '7',
#  '336',
#  '25',
#  '1,145',
#  '10',
#  '452',
#  '20',
#  '764',
#  '14',
#  '524',
#  '11',
#  '330',
#  '9',
#  '190',
#  '14',
#  '232',
#  '6',
#  '97',
#  '13',
#  '0']

# %%
ratings=[]

for i in soup.find_all('td',class_ = "table-body__cell u-text-right rating"):
    ratings.append(i.text)
    
ratings
# Out:
# ['119',
#  '116',
#  '113',
#  '98',
#  '93',
#  '91',
#  '84',
#  '83',
#  '62',
#  '48',
#  '46',
#  '45',
#  '38',
#  '37',
#  '30',
#  '21',
#  '17',
#  '16',
#  '0']

# %% [markdown]
# # mens batsman

# %%
page = requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC ODI Match Player Rankings International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC ODI Match Player Rankings International Cricket Council" property="og:title"/>
# ...

# %%
first_player = soup.find('div',class_ = "rankings-block__banner--name")
first_player
# Out:
# <div class="rankings-block__banner--name">Babar Azam</div>

# %%
first_player.text
# Out:
# 'Babar Azam'

# %%
country = soup.find('div',class_ = "rankings-block__banner--nationality")
country
# Out:
# <div class="rankings-block__banner--nationality">
# <div class="flag-15 PAK"></div>
# <span class="rankings-block__banner--nation"></span>PAK
#                             <div class="rankings-block__banner--rating">873</div>
# </div>

# %%
country.text
# Out:
# '\n\nPAK\n                            873\n'

# %%
rating = soup.find('div',class_= "rankings-block__banner--rating")
rating
# Out:
# <div class="rankings-block__banner--rating">873</div>

# %%
rating.text
# Out:
# '873'

# %%
players = []

for i in soup.find_all('td',class_ = "table-body__cell name"):
    players.append(i.text)
    
players
# Out:
# ['\nVirat Kohli\n',
#  '\nRohit Sharma\n',
#  '\nRoss Taylor\n',
#  '\nAaron Finch\n',
#  '\nJonny Bairstow\n',
#  '\nDavid Warner\n',
#  '\nShai Hope\n',
#  '\nKane Williamson\n',
#  '\nQuinton de Kock\n',
#  '\nJosh Hazlewood\n',
#  '\nMujeeb Ur Rahman\n',
#  '\nChris Woakes\n',
#  '\nMehedi Hasan\n',
#  '\nMatt Henry\n',
#  '\nJasprit Bumrah\n',
#  '\nMitchell Starc\n',
#  '\nShakib Al Hasan\n',
#  '\nKagiso Rabada\n',
#  '\nMohammad Nabi\n',
#  '\nChris Woakes\n',
#  '\nRashid Khan\n',
#  '\nMitchell Santner\n',
#  '\nBen Stokes\n',
#  '\nColin de Grandhomme\n',
#  '\nImad Wasim\n',
#  '\nRavindra Jadeja\n',
#  '\nSikandar Raza\n',
#  '\nVirat Kohli\n',
#  '\nRohit Sharma\n',
#  '\nRoss Taylor\n',
#  '\nAaron Finch\n',
#  '\nJonny Bairstow\n',
#  '\nDavid Warner\n',
#  '\nShai Hope\n',
#  '\nKane Williamson\n',
#  '\nQuinton de Kock\n',
#  '\nJosh Hazlewood\n',
#  '\nMujeeb Ur Rahman\n',
#  '\nChris Woakes\n',
#  '\nMehedi Hasan\n',
#  '\nMatt Henry\n',
#  '\nJasprit Bumrah\n',
# ...

# %%
countries = []

for i in soup.find_all('span',class_= "table-body__logo-text"):
    countries.append(i.text)
    
countries
# Out:
# ['IND',
#  'IND',
#  'NZ',
#  'AUS',
#  'ENG',
#  'AUS',
#  'WI',
#  'NZ',
#  'SA',
#  'AUS',
#  'AFG',
#  'ENG',
#  'BAN',
#  'NZ',
#  'IND',
#  'AUS',
#  'BAN',
#  'SA',
#  'AFG',
#  'ENG',
#  'AFG',
#  'NZ',
#  'ENG',
#  'NZ',
#  'PAK',
#  'IND',
#  'ZIM',
#  'IND',
#  'IND',
#  'NZ',
#  'AUS',
#  'ENG',
#  'AUS',
#  'WI',
#  'NZ',
#  'SA',
#  'AUS',
#  'AFG',
#  'ENG',
#  'BAN',
#  'NZ',
#  'IND',
#  'AUS',
#  'BAN',
#  'SA',
#  'AFG',
#  'ENG',
#  'AFG',
#  'NZ',
#  'ENG',
#  'NZ',
#  'PAK',
#  'IND',
#  'ZIM']

# %%
ratings=[]

for i in soup.find_all('td',class_= "table-body__cell u-text-right rating"):
    ratings.append(i.text)
    
ratings
# Out:
# ['844',
#  '813',
#  '801',
#  '779',
#  '775',
#  '762',
#  '758',
#  '754',
#  '743',
#  '709',
#  '708',
#  '700',
#  '692',
#  '691',
#  '679',
#  '652',
#  '650',
#  '643',
#  '294',
#  '282',
#  '270',
#  '268',
#  '266',
#  '257',
#  '256',
#  '238',
#  '229',
#  '844',
#  '813',
#  '801',
#  '779',
#  '775',
#  '762',
#  '758',
#  '754',
#  '743',
#  '709',
#  '708',
#  '700',
#  '692',
#  '691',
#  '679',
#  '652',
#  '650',
#  '643',
#  '294',
#  '282',
#  '270',
#  '268',
#  '266',
#  '257',
#  '256',
#  '238',
#  '229']

# %% [markdown]
# # Mens bowlers

# %%
page= requests.get('https://sports.ndtv.com/cricket/icc-rankings/odi-bowling')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
first_bowler = soup.find('span',class_="rnk_tbl-nm")
first_bowler
# Out:
# <span class="rnk_tbl-nm"><a href="/cricket/players/1061-trent-boult-playerprofile" title="Trent Boult"><span>Trent Boult</span></a> <span class="rnk_tbl-tm">New Zealand</span></span>

# %%
first_bowler.text
# Out:
# 'Trent Boult New Zealand'

# %%
rating = soup.find('td',class_="rnk_tbl-td rnk_tx-rt")
rating
# Out:
# <td class="rnk_tbl-td rnk_tx-rt">737</td>

# %%
rating.text
# Out:
# '737'

# %%
bowlers = []

for i in soup.find_all('span',class_="rnk_tbl-nm"):
    bowlers.append(i.text)
    
bowlers
# Out:
# ['Trent Boult New Zealand',
#  'Josh Hazlewood Australia',
#  'Mujeeb Ur Rahman Afghanistan',
#  'Chris Woakes England',
#  'Mehidy Hasan Bangladesh',
#  'Matt Henry New Zealand',
#  'Jasprit Bumrah India',
#  'Mitchell Starc Australia',
#  'Shakib Al Hasan Bangladesh',
#  'Kagiso Rabada South Africa',
#  'Mustafizur Rahman Bangladesh',
#  'Pat Cummins Australia',
#  'Shaheen Afridi Pakistan',
#  'Mohammad Amir Pakistan',
#  'Rashid Khan Afghanistan',
#  'Adam Zampa Australia',
#  'Bhuvneshwar Kumar India',
#  'Lockie Ferguson New Zealand',
#  'Jofra Archer England',
#  'Yuzvendra Chahal India',
#  'Mohammad Nabi Afghanistan',
#  'Mark Wood England',
#  'Alzarri Joseph West Indies',
#  'Lungi Ngidi South Africa',
#  'Mitchell Santner New Zealand',
#  'Akila Dananjaya Sri Lanka',
#  'Andy McBrine Ireland',
#  'Mohammed Shami India',
#  'Kuldeep Yadav India',
#  'Ravindra Jadeja India',
#  'Tabraiz Shamsi South Africa',
#  'Sheldon Cottrell West Indies',
# ...

# %%
ratings = []

for i in soup.find_all('td',class_="rnk_tbl-td rnk_tx-rt"):
    ratings.append(i.text)
    
ratings
# Out:
# ['737',
#  '770 v West Indies, 22/06/2019',
#  '709',
#  '733 v England, 26/01/2018',
#  '708',
#  '712 v Ireland, 24/01/2021',
#  '700',
#  '711 v Sri Lanka, 04/07/2021',
#  '692',
#  '725 v Sri Lanka, 25/05/2021',
#  '691',
#  '691 v Bangladesh, 26/03/2021',
#  '679',
#  '841 v West Indies, 01/11/2018',
#  '652',
#  '783 v New Zealand, 29/03/2015',
#  '650',
#  '717 v Zimbabwe, 05/11/2009',
#  '643',
#  '724 v England, 29/05/2017',
#  '640',
#  '695 v West Indies, 14/12/2018',
#  '636',
#  '729 v Pakistan, 12/06/2019',
#  '630',
#  '637 v England, 10/07/2021',
#  '628',
#  '663 v Sri Lanka, 02/10/2019',
#  '626',
#  '806 v Pakistan, 21/09/2018',
#  '625',
#  '625 v West Indies, 26/07/2021',
#  '621',
#  '657 v West Indies, 17/10/2014',
#  '619',
#  '668 v West Indies, 22/06/2019',
#  '609',
#  '642 v Australia, 13/09/2020',
#  '603',
#  '730 v New Zealand, 23/01/2019',
#  '596',
#  '653 v Zimbabwe, 26/02/2017',
#  '594',
#  '615 v Afghanistan, 18/06/2019',
#  '592',
# ...

# %%
page = requests.get('https://www.cricbuzz.com/cricket-stats/icc-rankings/women/teams')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
first_team = soup.find('div',class_ ="cb-col cb-col-50 cb-lst-itm-sm text-left")
first_team
# Out:
# <div class="cb-col cb-col-50 cb-lst-itm-sm text-left">AUSTRALIA WOMEN</div>

# %%
first_team.text
# Out:
# 'AUSTRALIA WOMEN'

# %%
rating = soup.find('div',class_ ="cb-col cb-col-14 cb-lst-itm-sm")
rating
# Out:
# <div class="cb-col cb-col-14 cb-lst-itm-sm">162</div>

# %%
rating.text
# Out:
# '162'

# %%
point = soup.find('div',class_="cb-col cb-col-14 cb-lst-itm-sm")
point
# Out:
# <div class="cb-col cb-col-14 cb-lst-itm-sm">162</div>

# %%
point.text
# Out:
# '162'

# %%
teams =[]

for i in soup.find_all('div',class_ ="cb-col cb-col-50 cb-lst-itm-sm text-left"):
    teams.append(i.text)
teams
# Out:
# ['AUSTRALIA WOMEN',
#  'SOUTH AFRICA WOMEN',
#  'ENGLAND WOMEN',
#  'INDIA WOMEN',
#  'BANGLADESH WOMEN',
#  'NEW ZEALAND WOMEN',
#  'WEST INDIES WOMEN',
#  'PAKISTAN WOMEN',
#  'IRELAND WOMEN',
#  'SRI LANKA WOMEN',
#  'ZIMBABWE WOMEN',
#  'AUSTRALIA WOMEN',
#  'ENGLAND WOMEN',
#  'INDIA WOMEN',
#  'NEW ZEALAND WOMEN',
#  'SOUTH AFRICA WOMEN',
#  'WEST INDIES WOMEN',
#  'PAKISTAN WOMEN',
#  'SRI LANKA WOMEN',
#  'BANGLADESH WOMEN',
#  'THAILAND WOMEN',
#  'ZIMBABWE WOMEN',
#  'IRELAND WOMEN',
#  'SCOTLAND WOMEN',
#  'PAPUA NEW GUINEA WOMEN',
#  'SAMOA WOMEN',
#  'NEPAL WOMEN',
#  'UAE WOMEN',
#  'TANZANIA WOMEN',
#  'UGANDA WOMEN',
#  'NETHERLANDS WOMEN',
#  'NAMIBIA WOMEN',
#  'INDONESIA WOMEN',
#  'KENYA WOMEN',
#  'HONG KONG WOMEN',
#  'GERMANY WOMEN',
#  'CHINA WOMEN',
#  'UNITED STATES WOMEN',
#  'BRAZIL WOMEN',
#  'VANUATU WOMEN',
#  'JAPAN WOMEN',
#  'RWANDA WOMEN',
#  'MALAYSIA WOMEN',
#  'FRANCE WOMEN',
#  'OMAN WOMEN',
#  'BOTSWANA WOMEN',
#  'AUSTRIA WOMEN',
# ...

# %%
ratings=[]

for i in soup.find_all('div',class_ ="cb-col cb-col-14 cb-lst-itm-sm"):
    ratings.append(i.text)
ratings
# Out:
# ['162',
#  '2746',
#  '121',
#  '2307',
#  '119',
#  '2148',
#  '112',
#  '1899',
#  '95',
#  '475',
#  '88',
#  '1668',
#  '87',
#  '1658',
#  '68',
#  '1226',
#  '48',
#  '240',
#  '47',
#  '233',
#  '0',
#  '0',
#  '291',
#  '5824',
#  '286',
#  '7157',
#  '264',
#  '6081',
#  '264',
#  '4487',
#  '252',
#  '5030',
#  '247',
#  '4691',
#  '224',
#  '4027',
#  '200',
#  '1600',
#  '190',
#  '2094',
#  '168',
#  '2851',
#  '161',
#  '2730',
#  '160',
#  '3209',
#  '152',
#  '2429',
#  '130',
#  '1174',
#  '125',
#  '749',
#  '124',
#  '989',
#  '120',
#  '837',
#  '112',
#  '1340',
#  '104',
#  '1350',
#  '90',
#  '1527',
#  '87',
#  '1911',
#  '85',
#  '761',
#  '84',
#  '1010',
#  '75',
#  '677',
#  '70',
#  '1112',
#  '67',
#  '538',
#  '60',
#  '540',
#  '58',
#  '465',
#  '54',
#  '324',
#  '52',
#  '260',
#  '49',
#  '1025',
#  '45',
#  '358',
#  '26',
#  '315',
#  '26',
#  '129',
#  '23',
#  '317',
#  '23',
#  '316',
#  '21',
#  '126',
#  '18',
#  '73',
#  '18',
#  '71',
# ...

# %% [markdown]
# # woman batsman

# %%
page = requests.get('https://www.cricbuzz.com/cricket-stats/icc-rankings/women/batting')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
team = soup.find('div',class_="cb-font-12 text-gray")
team
# Out:
# <div class="cb-font-12 text-gray">SOUTH AFRICA</div>

# %%
team.text
# Out:
# 'SOUTH AFRICA'

# %%
rating = soup.find('div',class_="cb-col cb-col-17 cb-rank-tbl pull-right")
rating
# Out:
# <div class="cb-col cb-col-17 cb-rank-tbl pull-right">761</div>

# %%
rating.text
# Out:
# '761'

# %%
teams=[]

for i in soup.find_all('div',class_="cb-font-12 text-gray"):
    teams.append(i.text)
teams
# Out:
# ['SOUTH AFRICA',
#  'AUSTRALIA',
#  'INDIA',
#  'ENGLAND',
#  'NEW ZEALAND',
#  'INDIA',
#  'AUSTRALIA',
#  'AUSTRALIA',
#  'WEST INDIES',
#  'ENGLAND',
#  'SOUTH AFRICA',
#  'AUSTRALIA',
#  'AUSTRALIA',
#  'SOUTH AFRICA',
#  'ENGLAND',
#  'WEST INDIES',
#  'NEW ZEALAND',
#  'INDIA',
#  'SRI LANKA',
#  'INDIA',
#  'SOUTH AFRICA',
#  'ENGLAND',
#  'INDIA',
#  'NEW ZEALAND',
#  'BANGLADESH',
#  'PAKISTAN',
#  'SOUTH AFRICA',
#  'AUSTRALIA',
#  'WEST INDIES',
#  'BANGLADESH',
#  'ENGLAND',
#  'PAKISTAN',
#  'PAKISTAN',
#  'NEW ZEALAND',
#  'IRELAND',
#  'PAKISTAN',
#  'PAKISTAN',
#  'NEW ZEALAND',
#  'ENGLAND',
#  'ENGLAND',
#  'IRELAND',
#  'SOUTH AFRICA',
#  'NEW ZEALAND',
#  'NEW ZEALAND',
#  'PAKISTAN',
#  'NEW ZEALAND',
#  'AUSTRALIA',
#  'SOUTH AFRICA',
#  'AUSTRALIA',
#  'INDIA',
#  'SOUTH AFRICA',
#  'SRI LANKA',
#  'INDIA',
#  'PAKISTAN',
#  'IRELAND',
#  'AUSTRALIA',
#  'SRI LANKA',
#  'INDIA',
#  'BANGLADESH',
#  'WEST INDIES',
#  'SOUTH AFRICA',
#  'WEST INDIES',
# ...

# %%
ratings =[]

for i in soup.find_all('div',class_="cb-col cb-col-17 cb-rank-tbl pull-right"):
    ratings.append(i.text)
ratings
# Out:
# ['761',
#  '750',
#  '738',
#  '728',
#  '717',
#  '710',
#  '699',
#  '690',
#  '676',
#  '674',
#  '672',
#  '668',
#  '649',
#  '648',
#  '642',
#  '578',
#  '563',
#  '559',
#  '552',
#  '543',
#  '538',
#  '537',
#  '537',
#  '530',
#  '512',
#  '504',
#  '489',
#  '477',
#  '477',
#  '476',
#  '466',
#  '458',
#  '457',
#  '449',
#  '438',
#  '425',
#  '425',
#  '424',
#  '409',
#  '403',
#  '393',
#  '386',
#  '377',
#  '373',
#  '369',
#  '358',
#  '358',
#  '350',
#  '349',
#  '346',
#  '345',
#  '336',
#  '330',
#  '320',
#  '318',
#  '317',
#  '313',
#  '309',
#  '300',
#  '293',
#  '291',
#  '290',
#  '290',
#  '284',
#  '284',
#  '283',
#  '279',
#  '272',
#  '271',
#  '270',
#  '266',
#  '266',
#  '261',
#  '259',
#  '258',
#  '253',
#  '248',
#  '242',
#  '241',
#  '240',
#  '237',
#  '235',
#  '233',
#  '231',
#  '228',
#  '227',
#  '226',
#  '226',
#  '225',
#  '221',
#  '221',
#  '217',
#  '213',
#  '212',
#  '212',
#  '211',
#  '211',
#  '208',
#  '207',
#  '206',
# ...

# %% [markdown]
# # woman all-rounder

# %%
page = requests.get('https://www.cricbuzz.com/cricket-stats/icc-rankings/women/all-rounder')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
team = soup.find('div',class_= "cb-font-12 text-gray")
team
# Out:
# <div class="cb-font-12 text-gray">SOUTH AFRICA</div>

# %%
team.text
# Out:
# 'SOUTH AFRICA'

# %%
rating = soup.find('div',class_="cb-col cb-col-17 cb-rank-tbl pull-right")
rating
# Out:
# <div class="cb-col cb-col-17 cb-rank-tbl pull-right">384</div>

# %%
rating.text
# Out:
# '384'

# %%
teams =[]
for i in soup.find_all('div',class_= "cb-font-12 text-gray"):
    teams.append(i.text)
teams
# Out:
# ['SOUTH AFRICA',
#  'ENGLAND',
#  'AUSTRALIA',
#  'WEST INDIES',
#  'INDIA',
#  'AUSTRALIA',
#  'SOUTH AFRICA',
#  'WEST INDIES',
#  'AUSTRALIA',
#  'ENGLAND',
#  'NEW ZEALAND',
#  'ENGLAND',
#  'SCOTLAND',
#  'INDIA',
#  'WEST INDIES',
#  'WEST INDIES',
#  'AUSTRALIA',
#  'SRI LANKA',
#  'BANGLADESH',
#  'AUSTRALIA']

# %%
ratings = []

for i in soup.find_all('div',class_="cb-col cb-col-17 cb-rank-tbl pull-right"):
    ratings.append(i.text)
ratings
# Out:
# ['384',
#  '372',
#  '365',
#  '319',
#  '299',
#  '275',
#  '274',
#  '272',
#  '272',
#  '272',
#  '370',
#  '362',
#  '327',
#  '315',
#  '292',
#  '288',
#  '273',
#  '265',
#  '263',
#  '261']

# %% [markdown]
# ### 7) Write a python program to scrape details of all the posts from coreyms.com. Scrape the heading, date, content
# ### and the code for the video from the link for the youtube video from the post.

# %%
page = requests.get('https://coreyms.com/')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- This site is optimized with the Yoast SEO plugin v15.4 - https://yoast.com/wordpress/plugins/seo/ -->
# <title>CoreyMS - Development, Design, DIY, and more</title>
# <meta content="Development, Design, DIY, and more" name="description"/>
# <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>
# <link href="https://coreyms.com/" rel="canonical"/>
# <link href="https://coreyms.com/page/2" rel="next"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="website" property="og:type"/>
# <meta content="CoreyMS - Development, Design, DIY, and more" property="og:title"/>
# <meta content="Development, Design, DIY, and more" property="og:description"/>
# <meta content="https://coreyms.com/" property="og:url"/>
# <meta content="CoreyMS" property="og:site_name"/>
# ...

# %%
Heading = soup.find('a',class_="entry-title-link")
Heading
# Out:
# <a class="entry-title-link" href="https://coreyms.com/development/python/python-tutorial-zip-files-creating-and-extracting-zip-archives" rel="bookmark">Python Tutorial: Zip Files – Creating and Extracting Zip Archives</a>

# %%
Heading.text
# Out:
# 'Python Tutorial: Zip Files – Creating and Extracting Zip Archives'

# %%
date = soup.find('time',class_="entry-time")
date
# Out:
# <time class="entry-time" datetime="2019-11-19T13:02:37-05:00" itemprop="datePublished">November 19, 2019</time>

# %%
date.text
# Out:
# 'November 19, 2019'

# %%
content = soup.find('div',class_="entry-content")
content
# Out:
# <div class="entry-content" itemprop="text">
# <p>In this video, we will be learning how to create and extract zip archives. We will start by using the zipfile module, and then we will see how to do this using the shutil module. We will learn how to do this with single files and directories, as well as learning how to use gzip as well. Let’s get started…<br/></p>
# <span class="embed-youtube" style="text-align:center; display: block;"><iframe allowfullscreen="true" class="youtube-player" height="360" sandbox="allow-scripts allow-same-origin allow-popups allow-presentation" src="https://www.youtube.com/embed/z0gguhEmWiY?version=3&amp;rel=1&amp;showsearch=0&amp;showinfo=1&amp;iv_load_policy=1&amp;fs=1&amp;hl=en-US&amp;autohide=2&amp;wmode=transparent" style="border:0;" width="640"></iframe></span>
# </div>

# %%
content.text
# Out:
# '\nIn this video, we will be learning how to create and extract zip archives. We will start by using the zipfile module, and then we will see how to do this using the shutil module. We will learn how to do this with single files and directories, as well as learning how to use gzip as well. Let’s get started…\n\n'

# %%
vedio = soup.find('a',class_="ytp-title-link yt-uix-sessionlink")
vedio

# %%
page = requests.get('https://www.nobroker.in/property/sale/bangalore/multiple?searchParam=...')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta content="794951570520699" property="fb:pages"/>
# <link href="https://www.nobroker.in" rel="canonical"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in" rel="dns-prefetch"/>
# <link href="//images.nobroker.in" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in/static/img/favicon.png" id="favicon" rel="shortcut icon"/>
# <link href="https://images.nobroker.in/static/img/fav64.png" rel="apple-touch-icon"/>
# <meta charset="utf-8"/><meta charset="utf-8"/>
# <meta content="app-id=com.nobroker.app&amp;referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb" name="google-play-app"/>
# <meta content="app-id=1200507100, app-argument=nobrokerapp://" name="apple-itunes-app"/>
# <meta content="#fd3752" name="theme-color"/>
# ...

# %%
title = soup.find('a',class_="nb__U5JyW")
title
# Out:
# <a class="nb__U5JyW" href="/property/buy/3-bhk-apartment-for-sale-in-jayanagara-9th-block-jayanagar-bangalore/8a9fb8827d328084017d329fb16a0fde/detail" itemprop="url" target="_blank" title="3 BHK Flat  For Sale  In Shanti Park Apartments In Jayanagara 9th Block, Jayanagar"><h2 class="heading-6 font-semi-bold nb__25Cl7"><span itemprop="name">3 BHK Flat  For Sale  In Shanti Park Apartments In Jayanagara 9th Block, Jayanagar</span> <svg class="" style="width:24px;height:24px;margin:2px" type="link" viewbox="0 0 24 24"><path class="" d="M18,10.82a1,1,0,0,0-1,1V19a1,1,0,0,1-1,1H5a1,1,0,0,1-1-1V8A1,1,0,0,1,5,7h7.18a1,1,0,0,0,0-2H5A3,3,0,0,0,2,8V19a3,3,0,0,0,3,3H16a3,3,0,0,0,3-3V11.82A1,1,0,0,0,18,10.82Zm3.92-8.2a1,1,0,0,0-.54-.54A1,1,0,0,0,21,2H15a1,1,0,0,0,0,2h3.59L8.29,14.29a1,1,0,0,0,0,1.42,1,1,0,0,0,1.42,0L20,5.41V9a1,1,0,0,0,2,0V3A1,1,0,0,0,21.92,2.62Z" fill="#000000"></path></svg></h2></a>

# %%
title.text
# Out:
# '3 BHK Flat  For Sale  In Shanti Park Apartments In Jayanagara 9th Block, Jayanagar '

# %%
locality = soup.find('div',class_="nb__1EwQz")
locality
# Out:
# <div class="nb__1EwQz">Shanti Park Apartments</div>

# %%
locality.text
# Out:
# 'Shanti Park Apartments'

# %%
emi = soup.find('div',class_="nb__4L90a")
emi
# Out:
# <div class="nb__4L90a" style="width:fit-content;padding:0 10px"><meta content="Title verification and loan availability" itemprop="name"/><span class="nb__2uIga"><span class="nb__2KN_6 nb__H3vjf">Not under loan</span><span style="color:#fff;border-radius:50%;padding:0 5px;background:#ccc"><span>₹</span> </span></span></div>

# %%
emi.text
# Out:
# 'Not under loan₹ '

# %%
price = soup.find('div',class_="nb__4L90a")
price
# Out:
# <div class="nb__4L90a" style="width:fit-content;padding:0 10px"><meta content="Title verification and loan availability" itemprop="name"/><span class="nb__2uIga"><span class="nb__2KN_6 nb__H3vjf">Not under loan</span><span style="color:#fff;border-radius:50%;padding:0 5px;background:#ccc"><span>₹</span> </span></span></div>

# %%
price.text
# Out:
# 'Not under loan₹ '

# %%
page = requests.get('https://www.bewakoof.com/women-tshirts?ga_q=tshirts')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <link href="https://images.bewakoof.com" hreflang="en-in" rel="preconnect"/>
# <link href="https://images.bewakoof.com" hreflang="en-in" rel="dns-prefetch"/>
# <link href="https://static.bewakoof.com" hreflang="en-in" rel="preconnect"/>
# <link href="https://static.bewakoof.com" hreflang="en-in" rel="dns-prefetch"/>
# <link href="https://cdn.polyfill.io" hreflang="en-in" rel="preconnect"/>
# <link href="https://cdn.polyfill.io" hreflang="en-in" rel="dns-prefetch"/>
# <link href="https//www.googletagmanager.com" hreflang="en-in" rel="preconnect"/>
# <link href="https//www.googletagmanager.com" hreflang="en-in" rel="dns-prefetch"/>
# <link href="https://fonts.gstatic.com" hreflang="en-in" rel="preconnect"/>
# <link href="https://fonts.gstatic.com" hreflang="en-in" rel="dns-prefetch"/>
# <link href="https://www.google-analytics.com" hreflang="en-in" rel="dns-prefetch"/>
# <link href="https://connect.facebook.net" hreflang="en-in" rel="dns-prefetch"/>
# ...

# %%
name = soup.find('div',class_="productCardDetail ")
name

# %%
name.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-1d56b9654ee2> in <module>
# ----> 1 name.text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
price = soup.find('span',class_="discountedPriceText")
price
# Out:
# <span class="discountedPriceText">₹ <b>199</b></span>

# %%
price.text
# Out:
# '₹ 199'

# %%
image = soup.find('img',class_="productImgTag")
image
# Out:
# <img alt="Shop Dab Marshmello Half Sleeve T-Shirt-Front" class="productImgTag" src="https://images.bewakoof.com/t320/dab-marshmello-half-sleeve-t-shirt-women-s-half-sleeve-printed-t-shirt-284092-1602133550.jpg" title="Dab Marshmello Half Sleeve T-Shirt-Front Bewakoof"/>

# %%
image.text
# Out:
# ''
